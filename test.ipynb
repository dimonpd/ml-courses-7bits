# %%
import pandas as pd
import statistics

# %%
p =[1,1,1,1,1,1]

# %%
data = pd.Series(p)

# %%
data.std()
# Out:
# 1.7511900715418263

# %%
tekst = input()
print(tekst)
# Out:
# sddsd

# %%
import pandas as pd

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1qUlm3ZRJ20s0BUR58MqPdSzP-ec3g0i4')

# %%
df
# Out:
#            Date Region    Product  SalesCount
# 0    2022-01-03  South  Product C         716
# 1    2022-01-04  South  Product C        1623
# 2    2022-01-07  South  Product A        1159
# 3    2022-01-12   West  Product B         501
# 4    2022-01-21   East  Product B        1567
# ..          ...    ...        ...         ...
# 205  2023-12-02  North  Product A        1288
# 206  2023-12-19  North  Product B         798
# 207  2023-12-23  North  Product B        1145
# 208  2023-12-26  South  Product B        1072
# 209  2023-12-27  North  Product C        1439
#
# [210 rows x 4 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 205    2023
# 206    2023
# 207    2023
# 208    2023
# 209    2023
# Name: Date, Length: 210, dtype: int32

# %% [markdown]
# Найдите продукт, который чаще всего продавался в регионе "Запад" в 2023 году
# День недели, в который было совершено больше всего продаж.
# День-рекордсмен по продажам.

# %%
df.loc[(df['Region'] == 'West') & (df['Date'].dt.year == 2023)].groupby('Product')['SalesCount'].sum()
# Out:
# Product
# Product A    13259
# Product B    11008
# Product C     7898
# Name: SalesCount, dtype: int64

# %%
df['day_of_week'] = df['Date'].dt.day_name()

# %%
df
# Out:
#           Date Region    Product  SalesCount day_of_week
# 0   2022-01-03  South  Product C         716      Monday
# 1   2022-01-04  South  Product C        1623     Tuesday
# 2   2022-01-07  South  Product A        1159      Friday
# 3   2022-01-12   West  Product B         501   Wednesday
# 4   2022-01-21   East  Product B        1567      Friday
# ..         ...    ...        ...         ...         ...
# 205 2023-12-02  North  Product A        1288    Saturday
# 206 2023-12-19  North  Product B         798     Tuesday
# 207 2023-12-23  North  Product B        1145    Saturday
# 208 2023-12-26  South  Product B        1072     Tuesday
# 209 2023-12-27  North  Product C        1439   Wednesday
#
# [210 rows x 5 columns]

# %%
df.groupby(by='day_of_week')['SalesCount'].sum().sort_values(ascending=False)
# Out:
# day_of_week
# Saturday     46068
# Wednesday    39978
# Tuesday      39572
# Sunday       37014
# Thursday     36999
# Monday       34027
# Friday       33324
# Name: SalesCount, dtype: int64

# %%
df.groupby('Date')['SalesCount'].first().reset_index().sort_values(by='SalesCount', ascending=False )
# Out:
#           Date  SalesCount
# 96  2023-01-13        1999
# 101 2023-01-27        1995
# 128 2023-04-16        1993
# 92  2022-12-27        1989
# 43  2022-06-10        1979
# ..         ...         ...
# 141 2023-06-06         530
# 103 2023-02-02         514
# 67  2022-09-23         512
# 117 2023-03-20         504
# 3   2022-01-12         501
#
# [210 rows x 2 columns]

# %%
pd.read_excel('data.xlsx')
# Out:
#     ууу  dddd  ddd
# 0   NaN   NaN  NaN
# 1   NaN   NaN  NaN
# 2  dddd   NaN  NaN

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1HIjPFp64E3uR_RxMFUJRXodmKCbOESIY', sep=';')

# %%
df
# Out:
#                   Name  Gender   Age    Wage                     Occupation  \
# 0         Anna Ivanova  Female  28.0  3500.0                 Data Scientist
# 1         Boris Petrov     NaN  45.0  5000.0                       Engineer
# 2       Viktor Sidorov    Male  33.0     NaN             Software Developer
# 3       Elena Smirnova  Female  27.0  3800.0                            NaN
# 4         Sergey Orlov    Male   NaN  4800.0                Project Manager
# 5        Maria Volkova  Female  35.0  4600.0                     HR Manager
# 6       Ivan Kuznetsov    Male  29.0     NaN           Marketing Specialist
# 7         Olga Pavlova  Female   NaN  5200.0                Product Manager
# 8       Dmitry Lebedev     NaN  32.0  4300.0                            NaN
# 9      Tatiana Vlasova  Female   NaN  3700.0               Business Analyst
# 10    Alexey Goncharov    Male  42.0  5100.0                            NaN
# ...

# %%
missing_proportion = df.isna().sum().sum() / (df.shape[0] * df.shape[1])
round(missing_proportion, 2)
# Out:
# 0.21

# %%
df.isnull().sum().sum()
# Out:
# 66

# %%
df.shape
# Out:
# (44, 7)

# %%
66 / (44*7)
# Out:
# 0.21428571428571427

# %%
df.dtypes
# Out:
# Name           object
# Gender         object
# Age           float64
# Wage          float64
# Occupation     object
# City           object
# Experience    float64
# dtype: object

# %%
df.shape
# Out:
# (44, 7)

# %%
df2  = pd.read_csv('https://drive.google.com/uc?export=download&id=1GztFVF32hUQkzDD-kHfH37vstbvwKJwp')

# %%
df2
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %% [markdown]
# ам дан датасет. По нему, найдите:
#
# Значение 'Avg. Session Length' у человека с максимальным значением 'Time on App'
# Коэффициент корреляции Спирмэна между столбцами 'Yearly Amount Spent' и 'Length of Membership'
# Значение 'Length of Membership', ниже которого находится 40% всех значений
# Все ответы округлите до сотых, в качестве разделителя используйте точку. В поле для ответа запишите ответы на вопросы сверху, разделенные символом «;». Если ответы равны 13.544231, 0.5325533 и 54.43678, то ответ должен выглядеть так: «13.54;0.53;54.44»

# %% [markdown]
# ### 'Avg. Session Length' у человека с максимальным значением 'Time on App' 34.374258

# %%
df2.sort_values(by='Time on App', ascending=False)
# Out:
#                                 Email  \
# 65                     kyang@diaz.org
# 18            alejandro75@hotmail.com
# 260              george02@hotmail.com
# 286            bhill@pierce-kane.info
# 340           vancealicia@hotmail.com
# ..                                ...
# 61             floresarthur@yahoo.com
# 369                david80@knight.com
# 362                   cruiz@yahoo.com
# 442  martinkristi@sanchez-coleman.com
# 309                  dblair@gmail.com
#
#                                                Address            Avatar  \
# 65    223 Love Trail Suite 831\nPort Jeffrey, IN 46849         OliveDrab
# 18   64475 Andre Club Apt. 795\nPort Dannytown, PW ...              Cyan
# 260      3286 Lynch Field\nHenrychester, RI 41833-7902        LightCoral
# 286  3324 Branch Squares Suite 221\nRiddleton, OK 3...         RoyalBlue
# 340  06307 Scott Spurs Suite 161\nJessicaburgh, NH ...         RoyalBlue
# ...

# %% [markdown]
# ### Коэффициент корреляции Спирмэна между столбцами 'Yearly Amount Spent' и 'Length of Membership'

# %%
df2['Yearly Amount Spent'].corr(df2['Length of Membership'], method='spearman')
# Out:
# 0.7799147996591986

# %% [markdown]
# ### Значение 'Length of Membership', ниже которого находится 40% всех значений

# %%
df2['Length of Membership'].quantile(0.4)
# Out:
# 3.315968748387908

# %%
df3 = pd.read_csv('https://drive.google.com/uc?export=download&id=1Ol1sjmGtBEQ2L7hMaxChxiddn6kgj7hs', sep=';')

# %%
df3
# Out:
#           Agent Name  Agent age        Time of deal   Price  hour
# 0           John Doe         35 2024-10-30 12:34:00  150.50    12
# 1         Jane Smith         45 2024-10-30 09:45:00  320.00     9
# 2    Michael Johnson         28 2024-10-30 14:12:00  260.75    14
# 3        Emily Davis         30 2024-10-30 16:50:00  180.10    16
# 4       Chris Wilson         50 2024-10-30 10:25:00  400.25    10
# ..               ...        ...                 ...     ...   ...
# 81   Avery Hernandez         44 2024-10-30 15:40:00  185.35    15
# 82    James Martinez         38 2024-10-30 11:15:00  170.90    11
# 83         Mia Evans         52 2024-10-30 12:10:00  240.20    12
# 84  Alexander Turner         37 2024-10-30 10:20:00  210.50    10
# 85          Zoe Bell         25 2024-10-30 12:55:00  145.70    12
#
# [86 rows x 5 columns]

# %% [markdown]
# - Найдите час, в который чаще всего совершались сделки. (Подсказка: из ячеек формата DateTime можно извлечь час с помощью .dt.hour; например data['Date'].dt.hour)
#
# def get_age_group(age):
#     if age <= 35:
#         return 'Young'
#     elif age <= 55:
#         return 'Middle-aged'
#     else:
#         return 'Senior'
#
# data['age_group'] = data['age'].apply(get_age_group)
# data[data['agent'] == 1]['age_group'].mode()

# %%
df3['Time of deal'] = pd.to_datetime(df3['Time of deal'])
df3['hour'] = df3['Time of deal'].dt.hour

# %%
df3
# Out:
#           Agent Name  Agent age        Time of deal   Price  hour
# 0           John Doe         35 2024-10-30 12:34:00  150.50    12
# 1         Jane Smith         45 2024-10-30 09:45:00  320.00     9
# 2    Michael Johnson         28 2024-10-30 14:12:00  260.75    14
# 3        Emily Davis         30 2024-10-30 16:50:00  180.10    16
# 4       Chris Wilson         50 2024-10-30 10:25:00  400.25    10
# ..               ...        ...                 ...     ...   ...
# 81   Avery Hernandez         44 2024-10-30 15:40:00  185.35    15
# 82    James Martinez         38 2024-10-30 11:15:00  170.90    11
# 83         Mia Evans         52 2024-10-30 12:10:00  240.20    12
# 84  Alexander Turner         37 2024-10-30 10:20:00  210.50    10
# 85          Zoe Bell         25 2024-10-30 12:55:00  145.70    12
#
# [86 rows x 5 columns]

# %%
df3.groupby('hour').count()
# Out:
#       Agent Name  Agent age  Time of deal  Price
# hour
# 9             12         12            12     12
# 10            11         11            11     11
# 11             9          9             9      9
# 12            13         13            13     13
# 13             9          9             9      9
# 14             9          9             9      9
# 15             9          9             9      9
# 16            10         10            10     10
# 17             4          4             4      4

# %%
rounded_price = df3['Price'].round()
mean = round(rounded_price.mean(), 1)
median = round(rounded_price.median(), 1)
std = round(rounded_price.std(), 1)
print(mean, median, std)
# Out:
# 254.2 237.5 80.4

# %%
def get_age_group(age):
    if age <= 35:
        return 'Young'
    elif age <= 55:
        return 'Middle-aged'
    else:
        return 'Senior'

df3['age_group'] = df3['Agent age'].apply(get_age_group)
df3[df3['Agent Name'] == 1]['age_group'].mode()
# Out:
# Series([], Name: age_group, dtype: object)

# %%
df3['age_group'].value_counts()
# Out:
# age_group
# Middle-aged    38
# Young          36
# Senior         12
# Name: count, dtype: int64

# %%
import importlib

try:
    importlib.import_module('matplotlib')
    print("Модуль matplotlib доступен и готов к работе.")
except ModuleNotFoundError:
    print("Модуль matplotlib недоступен.")
# Out:
# Модуль matplotlib доступен и готов к работе.

# %%
import pandas as pd
from numpy import NaN
from sklearn.impute import KNNImputer

df = pd.DataFrame({'чупачупс': [3, 5, 4, 5],
                   'доширак': [4, 5, 3, 4],
                   'боярышник': [5, 5, 3, 3],
                   'ваз-2101': [3, 4, 2, 3],
                   'семечки': [4, 3, 5, NaN]},
                  index=['Вася', 'Петя', 'Маша', 'Саша'])

imputer = KNNImputer(n_neighbors=2)
df_imputed = imputer.fit_transform(df)

df_imputed = pd.DataFrame(df_imputed, columns=df.columns, index=df.index)
print(df_imputed)
# Out:
#       чупачупс  доширак  боярышник  ваз-2101  семечки
# Вася       3.0      4.0        5.0       3.0      4.0
# Петя       5.0      5.0        5.0       4.0      3.0
# Маша       4.0      3.0        3.0       2.0      5.0
# Саша       5.0      4.0        3.0       3.0      4.0

# %%
import numpy as np
from sklearn.impute import KNNImputer
nan = np.nan
X = [[1, 2, nan], [3, 4, 3], [nan, 6, 5], [8, 8, 7]]
imputer = KNNImputer(n_neighbors=2, weights="uniform")
imputer.fit_transform(X)
# Out:
# array([[1. , 2. , 4. ],
#        [3. , 4. , 3. ],
#        [5.5, 6. , 5. ],
#        [8. , 8. , 7. ]])

# %%
X
# Out:
# [[1, 2, nan], [3, 4, 3], [nan, 6, 5], [8, 8, 7]]
